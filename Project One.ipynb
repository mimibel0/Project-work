# %% [markdown]
# ### Mimibel Mireku Asare
# ### 10971054
# ### BIOMEDICAL ENDINEERING

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data.csv')

# %%
dataset
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dataset = dataset.drop_duplicates()
# Out:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
print(dataset.duplicated().sum())
# Out:
# 0

# %%
dataset.shape
# Out:
# (1601, 13)

# %%
print(dataset.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# fixed_acidity_mean = dataset['fixed acidity'].mean()
# citric_acid_mean = dataset['citric acid'].mean()
# chlorides_mean = dataset['chlorides'].mean()
# free_sulfur_dioxide_mean = dataset['free sulfur dioxide'].mean()
# total_sulfur_dioxide_mean = dataset['total sulfur dioxide'].mean()
# density_mean = dataset['density'].mean()
# pH_mean = dataset['pH'].mean()
# quality_mean = dataset['quality'].mean()

# %% [markdown]
# ### Reason for replacing null values with the mean of each column
# ##### If you have a large dataset with many missing values, you can increase the accuracy of your analysis by filling them in with the mean of the appropriate column.This is due to the fact that the mean is a representative number that can provide a good estimate of the missing value.

# %%
dataset['fixed acidity'] = dataset['fixed acidity'].fillna(fixed_acidity_mean)
dataset['citric acid'] = dataset['citric acid'].fillna(citric_acid_mean)
dataset['chlorides'] = dataset['chlorides'].fillna(chlorides_mean)
dataset['free sulfur dioxide'] = dataset['free sulfur dioxide'].fillna(free_sulfur_dioxide_mean)
dataset['total sulfur dioxide'] = dataset['total sulfur dioxide'].fillna(total_sulfur_dioxide_mean)
dataset['density'] = dataset['density'].fillna(density_mean)
dataset['pH'] = dataset['pH'].fillna(pH_mean)
dataset['quality'] = dataset['quality'].fillna(quality_mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 dataset['fixed acidity'] = dataset['fixed acidity'].fillna(fixed_acidity_mean)
#       2 dataset['citric acid'] = dataset['citric acid'].fillna(citric_acid_mean)
#       3 dataset['chlorides'] = dataset['chlorides'].fillna(chlorides_mean)
#
# NameError: name 'fixed_acidity_mean' is not defined

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
print(dataset.describe())
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %%
dataset['volatile acidity'].mode()
# Out:
# 0    0.6
# Name: volatile acidity, dtype: float64

# %%
dataset['residual sugar'].mode()
# Out:
# 0    2.0
# Name: residual sugar, dtype: float64

# %%
dataset['sulphates'].median()
# Out:
# 0.62

# %%
dataset['alcohol'].median()
# Out:
# 10.2

# %%
dataset['quality'].value_counts()
# Out:
# 5.0    681
# 6.0    639
# 7.0    199
# 4.0     53
# 8.0     18
# 3.0     10
# Name: quality, dtype: int64

# %%
dataset['residual sugar'].value_counts()
# Out:
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     118
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64

# %%
dataset['volatile acidity'].value_counts()
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.580    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %%
dataset['pH'].value_counts()
# Out:
# 3.30    58
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64

# %%
dataset['fixed acidity'].value_counts()
# Out:
# 7.2     68
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64

# %%
print(dataset['pH'].skew())
# Out:
# 0.19387794236926129

# %%
print(dataset['pH'].kurt())
# Out:
# 0.8093331973410369

# %%
print(dataset['quality'].skew())
# Out:
# 0.21703905931589543

# %%
print(dataset['quality'].kurt())
# Out:
# 0.2977112440374263

# %%
dataset.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268147         -0.009544    -0.153429
# fixed acidity        -0.268147       1.000000         -0.255570     0.671061
# volatile acidity     -0.009544      -0.255570          1.000000    -0.552917
# citric acid          -0.153429       0.671061         -0.552917     1.000000
# residual sugar       -0.031589       0.114601          0.001877     0.143518
# chlorides            -0.119363       0.093544          0.060826     0.204054
# free sulfur dioxide   0.091197      -0.153049         -0.010592    -0.061269
# total sulfur dioxide -0.113913      -0.113356          0.076249     0.036030
# density              -0.368825       0.667912          0.022771     0.364309
# pH                    0.135208      -0.682644          0.235306    -0.543019
# sulphates            -0.124243       0.182303         -0.261364     0.312895
# ...

# %%
corr_matrix = dataset.corr()
sb.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
numerical_cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
fig, axs = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))

# %%
axs = axs.flatten()

# %%
for i, col in enumerate(numerical_cols):...

# %%
for i in range(len(numerical_cols), len(axs)):
    fig.delaxes(axs[i])
fig.suptitle('Histograms Of Red Wine Characteristics')
plt.show()

# %%
fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.flatten()
for i, col in enumerate(numerical_cols):
    category_counts = dataset[col].value_counts()
    axs[i].pie(category_counts.values, labels=category_counts.index, autopct='%1.1f%%')
    axs[i].set_title(col)
    fig.suptitle('Distribution of Characteristics')
plt.show()

# %%
fig, axs = plt.subplots(4, 3, figsize=(20, 20))
axs = axs.flatten()
for i, column in enumerate(numerical_cols):
    axs[i].bar(dataset[column].value_counts().index, dataset[column].value_counts().values)
    axs[i].set_title(column)
    fig.suptitle('Distribution of Characteristics')
plt.show()
